# %%
import sys

sys.path.append('../')
import mustaching as ms


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load transactions

# %%
# Invent some sample transactions.
transactions = ms.create_transactions('2017-01-01', '2017-12-31')

# Alternatively, upload your own transactions as say 'my_transactions.csv' 
#transactions = ms.read_transactions('my_transactions.csv')

transactions.head(10)
# Out:
#                  date  amount description       comment     category
# 0 2017-01-01 00:00:00      91     0x8d7d4  0xac9162ff79    investing
# 1 2017-01-01 12:00:00      93     0x1cb26  0xf7381470d3    investing
# 2 2017-01-02 00:00:00      23     0x5f8ce  0xa205d265d3  programming
# 3 2017-01-02 12:00:00     -24     0x5c70b  0x7a5ac61d1c      shelter
# 4 2017-01-03 00:00:00      78     0x66e68  0xe827491859        reiki
# 5 2017-01-03 12:00:00     -25     0x3baa7  0xb1605976db   healthcare
# 6 2017-01-04 00:00:00     -41     0x136d2  0xbcfe8f98d1   healthcare
# 7 2017-01-04 12:00:00      46     0xc7114  0xd29d37e7fc  programming
# 8 2017-01-05 00:00:00       2     0x15f04  0x8875a7781b    investing
# 9 2017-01-05 12:00:00      -6     0xe51c9  0xa1293777b9      shelter

# %% [markdown]
# # Summarize transactions and plot

# %%
# Summarize over entire period by category
s1 = ms.summarize(transactions, decimals=2, by_category=True)
s1
# Out:
#         date      category  credit  debit  balance  savings_rate_for_period  \
# 0 2017-01-01          food       0   1475     8821                     0.44
# 1 2017-01-01    healthcare       0   1828     8821                     0.44
# 2 2017-01-01     investing    5343      0     8821                     0.44
# 3 2017-01-01   programming    8948      0     8821                     0.44
# 4 2017-01-01         reiki    5537      0     8821                     0.44
# 5 2017-01-01       shelter       0   3681     8821                     0.44
# 6 2017-01-01  soil testing       0   2190     8821                     0.44
# 7 2017-01-01     transport       0   1833     8821                     0.44
#
#    spending_rate_for_period  credit_frac_for_category_and_period  \
# 0                      0.56                                 0.00
# 1                      0.56                                 0.00
# 2                      0.56                                 0.27
# 3                      0.56                                 0.45
# 4                      0.56                                 0.28
# 5                      0.56                                 0.00
# 6                      0.56                                 0.00
# 7                      0.56                                 0.00
#
#    debit_frac_for_category_and_period  daily_avg  weekly_avg  monthly_avg  \
# 0                                0.13      -4.04      -28.29      -122.92
# 1                                0.17      -5.01      -35.06      -152.33
# 2                                0.00      14.64      102.47       445.25
# 3                                0.00      24.52      171.61       745.67
# 4                                0.00      15.17      106.19       461.42
# 5                                0.33     -10.08      -70.59      -306.75
# 6                                0.20      -6.00      -42.00      -182.50
# 7                                0.17      -5.02      -35.15      -152.75
#
#    yearly_avg
# 0     -1475.0
# 1     -1828.0
# 2      5343.0
# 3      8948.0
# 4      5537.0
# 5     -3681.0
# 6     -2190.0
# 7     -1833.0

# %%
ms.plot(s1)
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;lang&quot;: {&quot;thousandsSep&quot;: &quot;,&quot;}, &quot;global&quot;: {}}); var option = {&quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Account Summary&quot;}, &quot;drilldown&quot;: {}, &quot;loading&quot;: {}, &quot;exporting&quot;: {}, &quot;chart&quot;: {&quot;zoomType&quot;: &quot;xy&quot;, &quot;renderTo&quot;: &quot;container&quot;}, &quot;legend&quot;: {}, &quot;colors&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;Money&quot;}}, &quot;labels&quot;: {}, &quot;plotOptions&quot;: {&quot;column&quot;: {&quot;pointPadding&quot;: 0, &quot;borderWidth&quot;: 1, &quot;stacking&quot;: &quot;normal&quot;, &quot;borderColor&quot;: &quot;#333333&quot;}}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;series&quot;: {}, &quot;xAxis&quot;: {&quot;categories&quot;: [&quot;2017-01-01&quot;], &quot;type&quot;: &quot;category&quot;}, &quot;tooltip&quot;: {&quot;footerFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:1em\&quot;&gt;Column total&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.total:,.0f} \n &lt;/td&gt;\n &lt;/tr&gt;&lt;/table&gt;\n &quot;, &quot;useHTML&quot;: true, &quot;pointFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:1em\&quot;&gt;{series.name}\n ({point.percentage:.0f}%)&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.y:,.0f} \n &lt;/td&gt;\n &lt;/tr&gt;\n &quot;, &quot;headerFormat&quot;: &quot;&lt;b&gt;{point.key}&lt;/b&gt;&lt;table&gt;&quot;, &quot;shared&quot;: false}}; var chart = new Highcharts.Chart(option); var data = [{&quot;color&quot;: &quot;rgb(67,162,202)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit programming&quot;, &quot;data&quot;: [8948], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(168,221,181)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit reiki&quot;, &quot;data&quot;: [5537], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(224,243,219)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit investing&quot;, &quot;data&quot;: [5343], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(179,0,0)&quot;, &quot;stack&quot;: &quot;debit&quot;, &quot;name&quot;: &quot;Debit shelter&quot;, &quot;data&quot;: [3681], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(227,74,51)&quot;, &quot;stack&quot;: &quot;debit&quot;, &quot;name&quot;: &quot;Debit soil testing&quot;, &quot;data&quot;: [2190], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(252,141,89)&quot;, &quot;stack&quot;: &quot;debit&quot;, &quot;name&quot;: &quot;Debit transport&quot;, &quot;data&quot;: [1833], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quo ...

# %%
# Summarize by month start
s2 = ms.summarize(transactions, freq='MS', by_category=False, decimals=2)
s2
# Out:
#          date  credit  debit  balance  savings_rate_for_period  \
# 0  2017-01-01    1772    659     1113                     0.63
# 1  2017-02-01    1667    830     1950                     0.50
# 2  2017-03-01    1226   1120     2056                     0.09
# 3  2017-04-01    2160    638     3578                     0.70
# 4  2017-05-01    1965    893     4650                     0.55
# 5  2017-06-01    1674    733     5591                     0.56
# 6  2017-07-01    1520    843     6268                     0.45
# 7  2017-08-01    1521   1068     6721                     0.30
# 8  2017-09-01    1775    801     7695                     0.55
# 9  2017-10-01    1568   1189     8074                     0.24
# 10 2017-11-01    1564   1006     8632                     0.36
# 11 2017-12-01    1416   1227     8821                     0.13
#
#     spending_rate_for_period
# 0                       0.37
# 1                       0.50
# 2                       0.91
# 3                       0.30
# 4                       0.45
# 5                       0.44
# 6                       0.55
# 7                       0.70
# 8                       0.45
# 9                       0.76
# 10                      0.64
# 11                      0.87

# %%
ms.plot(s2)
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;lang&quot;: {&quot;thousandsSep&quot;: &quot;,&quot;}, &quot;global&quot;: {}}); var option = {&quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Account Summary&quot;}, &quot;drilldown&quot;: {}, &quot;loading&quot;: {}, &quot;exporting&quot;: {}, &quot;chart&quot;: {&quot;zoomType&quot;: &quot;xy&quot;, &quot;renderTo&quot;: &quot;container&quot;}, &quot;legend&quot;: {}, &quot;colors&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;Money&quot;}}, &quot;labels&quot;: {}, &quot;plotOptions&quot;: {&quot;column&quot;: {&quot;pointPadding&quot;: 0, &quot;borderWidth&quot;: 1, &quot;borderColor&quot;: &quot;#333333&quot;}}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;series&quot;: {}, &quot;xAxis&quot;: {&quot;categories&quot;: [&quot;2017-01-01&quot;, &quot;2017-02-01&quot;, &quot;2017-03-01&quot;, &quot;2017-04-01&quot;, &quot;2017-05-01&quot;, &quot;2017-06-01&quot;, &quot;2017-07-01&quot;, &quot;2017-08-01&quot;, &quot;2017-09-01&quot;, &quot;2017-10-01&quot;, &quot;2017-11-01&quot;, &quot;2017-12-01&quot;], &quot;type&quot;: &quot;category&quot;}, &quot;tooltip&quot;: {&quot;footerFormat&quot;: &quot;&lt;/table&gt;&quot;, &quot;useHTML&quot;: true, &quot;pointFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:1em\&quot;&gt;{series.name}&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.y:,.0f} \n &lt;/td&gt;\n &lt;/tr&gt;\n &quot;, &quot;headerFormat&quot;: &quot;&lt;b&gt;{point.key}&lt;/b&gt;&lt;table&gt;&quot;, &quot;shared&quot;: true}}; var chart = new Highcharts.Chart(option); var data = [{&quot;color&quot;: &quot;rgb(67,162,202)&quot;, &quot;name&quot;: &quot;Credit&quot;, &quot;data&quot;: [1772, 1667, 1226, 2160, 1965, 1674, 1520, 1521, 1775, 1568, 1564, 1416], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(227,74,51)&quot;, &quot;name&quot;: &quot;Debit&quot;, &quot;data&quot;: [659, 830, 1120, 638, 893, 733, 843, 1068, 801, 1189, 1006, 1227], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;#555&quot;, &quot;name&quot;: &quot;Balance&quot;, &quot;data&quot;: [1113, 1950, 2056, 3578, 4650, 5591, 6268, 6721, 7695, 8074, 8632, 8821], &quot;type&quot;: &quot;line&quot;}]; var dataLen = data.length; for (var ix = 0; ix &lt; dataLen; ix++) { chart.addSeries(data[ix]); } }); &lt;/script&gt; &lt;/body&gt; &lt;/html&gt;" height=520 width=820></iframe>

# %%
# Summarize by quarter start and by category
s3 = ms.summarize(transactions, freq='QS', by_category=True, decimals=2)
s3
# Out:
#          date      category  credit  debit  balance  savings_rate_for_period  \
# 0  2017-01-01          food       0    322     2056                     0.44
# 1  2017-01-01    healthcare       0    594     2056                     0.44
# 2  2017-01-01     investing    1117      0     2056                     0.44
# 3  2017-01-01   programming    2351      0     2056                     0.44
# 4  2017-01-01         reiki    1197      0     2056                     0.44
# 5  2017-01-01       shelter       0    811     2056                     0.44
# 6  2017-01-01  soil testing       0    451     2056                     0.44
# 7  2017-01-01     transport       0    431     2056                     0.44
# 8  2017-04-01          food       0    369     5591                     0.61
# 9  2017-04-01    healthcare       0    236     5591                     0.61
# 10 2017-04-01     investing    1560      0     5591                     0.61
# 11 2017-04-01   programming    2539      0     5591                     0.61
# 12 2017-04-01         reiki    1700      0     5591                     0.61
# 13 2017-04-01       shelter       0    743     5591                     0.61
# 14 2017-04-01  soil testing       0    548     5591                     0.61
# 15 2017-04-01     transport       0    368     5591                     0.61
# 16 2017-07-01          food       0    405     7695                     0.44
# 17 2017-07-01    healthcare       0    275     7695                     0.44
# 18 2017-07-01     investing    1216      0     7695                     0.44
# 19 2017-07-01   programming    1937      0     7695                     0.44
# 20 2017-07-01         reiki    1663      0     7695                     0.44
# 21 2017-07-01       shelter       0    862     7695                     0.44
# 22 2017-07-01  soil testing       0    567     7695                     0.44
# 23 2017-07-01     transport       0    603     7695                     0.44
# 24 2017-10-01          food       0    379     8821                     0.25
# 25 2017-10-01    healthcare       0    723     8821                     0.25
# 26 2017-10-01     investing    1450      0     8821                     0.25
# 27 2017-10-01   programming    2121      0     8821                     0.25
# 28 2017-10-01         reiki     977      0     8821                     0.25
# 29 2017-10-01       shelter       0   1265     8821                     0.25
# 30 2017-10-01  soil testing       0    624     8821                     0.25
# 31 2017-10-01     transport       0    431     8821                     0.25
#
#     spending_rate_for_period  credit_frac_for_category_and_period  \
# 0                       0.56                                 0.00
# 1                       0.56                                 0.00
# 2                       0.56                                 0.24
# 3                       0.56                                 0.50
# 4                       0.56                                 0.26
# 5                       0.56                                 0.00
# 6                       0.56                                 0.00
# 7                       0.56                                 0.00
# 8                       0.39                                 0.00
# 9                       0.39                                 0.00
# 10                      0.39                                 0.27
# 11                      0.39                                 0.44
# 12                      0.39                                 0.29
# 13                      0.39                                 0.00
# 14                      0.39                                 0.00
# 15                      0.39                                 0.00
# 16                      0.56                                 0.00
# 17                      0.56                                 0.00
# 18                      0.56                                 0.25
# 19                      0.56                                 0.40
# 20                      0.56                                 0.35
# 21                      0.56                                 0.00
# 22                      0.56                                 0.00
# 23                      0.56                                 0.00
# 24                      0.75                                 0.00
# 25                      0.75                                 0.00
# 26                      0.75                                 0.32
# 27                      0.75                                 0.47
# 28                      0.75                                 0.21
# 29                      0.75                                 0.00
# 30                      0.75                                 0.00
# 31                      0.75                                 0.00
#
#     debit_frac_for_category_and_period
# 0                                 0.12
# 1                                 0.23
# 2                                 0.00
# 3                                 0.00
# 4                                 0.00
# 5                                 0.31
# 6                                 0.17
# 7                                 0.17
# 8                                 0.16
# 9                                 0.10
# 10                                0.00
# 11                                0.00
# 12                                0.00
# 13                                0.33
# 14                                0.24
# 15                                0.16
# 16                                0.15
# 17                                0.10
# 18                                0.00
# 19                                0.00
# 20                                0.00
# 21                                0.32
# 22                                0.21
# 23                                0.22
# 24                                0.11
# 25                                0.21
# 26                                0.00
# 27                                0.00
# 28                                0.00
# 29                                0.37
# 30                                0.18
# 31                                0.13

# %%
ms.plot(s3)
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;lang&quot;: {&quot;thousandsSep&quot;: &quot;,&quot;}, &quot;global&quot;: {}}); var option = {&quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;Account Summary&quot;}, &quot;drilldown&quot;: {}, &quot;loading&quot;: {}, &quot;exporting&quot;: {}, &quot;chart&quot;: {&quot;zoomType&quot;: &quot;xy&quot;, &quot;renderTo&quot;: &quot;container&quot;}, &quot;legend&quot;: {}, &quot;colors&quot;: {}, &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;Money&quot;}}, &quot;labels&quot;: {}, &quot;plotOptions&quot;: {&quot;column&quot;: {&quot;pointPadding&quot;: 0, &quot;borderWidth&quot;: 1, &quot;stacking&quot;: &quot;normal&quot;, &quot;borderColor&quot;: &quot;#333333&quot;}}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;series&quot;: {}, &quot;xAxis&quot;: {&quot;categories&quot;: [&quot;2017-01-01&quot;, &quot;2017-04-01&quot;, &quot;2017-07-01&quot;, &quot;2017-10-01&quot;], &quot;type&quot;: &quot;category&quot;}, &quot;tooltip&quot;: {&quot;footerFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:1em\&quot;&gt;Column total&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.total:,.0f} \n &lt;/td&gt;\n &lt;/tr&gt;&lt;/table&gt;\n &quot;, &quot;useHTML&quot;: true, &quot;pointFormat&quot;: &quot;\n &lt;tr&gt;\n &lt;td style=\&quot;padding-right:1em\&quot;&gt;{series.name}\n ({point.percentage:.0f}%)&lt;/td&gt;\n &lt;td style=\&quot;text-align:right\&quot;&gt;{point.y:,.0f} \n &lt;/td&gt;\n &lt;/tr&gt;\n &quot;, &quot;headerFormat&quot;: &quot;&lt;b&gt;{point.key}&lt;/b&gt;&lt;table&gt;&quot;, &quot;shared&quot;: false}}; var chart = new Highcharts.Chart(option); var data = [{&quot;color&quot;: &quot;rgb(67,162,202)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit programming&quot;, &quot;data&quot;: [2351, 2539, 1937, 2121], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(168,221,181)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit reiki&quot;, &quot;data&quot;: [1197, 1700, 1663, 977], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(224,243,219)&quot;, &quot;stack&quot;: &quot;credit&quot;, &quot;name&quot;: &quot;Credit investing&quot;, &quot;data&quot;: [1117, 1560, 1216, 1450], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(179,0,0)&quot;, &quot;stack&quot;: &quot;debit&quot;, &quot;name&quot;: &quot;Debit shelter&quot;, &quot;data&quot;: [811, 743, 862, 1265], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(227,74,51)&quot;, &quot;stack&quot;: &quot;debit&quot;, &quot;name&quot;: &quot;Debit soil testing&quot;, &quot;data&quot;: [451, 548, 567, 624], &quot;type&quot;: &quot;column&quot;}, {&quot;color&quot;: &quot;rgb(252,141,89)&quot;, &quot;stack& ...
